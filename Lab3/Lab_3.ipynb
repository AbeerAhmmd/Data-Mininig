# %% [markdown]
# # Task 1:

# %% [markdown]
# • Create data frame with
#
# • 6 names of dinosaurs
#
# • Their favourite prime number. Play around with the frame

# %%
import pandas as pd

# %%
dinosaur_data = {
    'Dinosaur': ['Tyrannosaurus', 'Stegosaurus', 'Triceratops', 'Velociraptor', 'Brachiosaurus', 'Ankylosaurus'],
    'Favorite_Prime_Number': [2, 3, 5, 7, 11, 13]
}

# %%
dinosaur_df = pd.DataFrame(dinosaur_data)

# %%
print(dinosaur_df)
# Out:
#         Dinosaur  Favorite_Prime_Number
# 0  Tyrannosaurus                      2
# 1    Stegosaurus                      3
# 2    Triceratops                      5
# 3   Velociraptor                      7
# 4  Brachiosaurus                     11
# 5   Ankylosaurus                     13

# %%
print("Head of the DataFrame:")
df.head()
# Out:
# Head of the DataFrame:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# 3                        0.20                       40.03
# 4                        0.13                       20.93
#
#    Max. Edge Build Time / s  ...  Max. Init. Time / s  Presim. Time / s  \
# ...

# %%
print("\nShape of the DataFrame:")
df.shape
# Out:
# Shape of the DataFrame:
# (8, 21)

# %%
print("\nInformation about the DataFrame:")
df.info()
# Out:
# Information about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          8 non-null      int64
#  1   Nodes                       8 non-null      int64
#  2   Tasks/Node                  8 non-null      int64
#  3   Threads/Task                8 non-null      int64
#  4   Runtime Program / s         8 non-null      float64
#  5   Scale                       8 non-null      int64
#  6   Plastic                     8 non-null      bool
#  7   Avg. Neuron Build Time / s  8 non-null      float64
#  8   Min. Edge Build Tim  e / s  8 non-null      float64
#  9   Max. Edge Build Time / s    8 non-null      float64
#  10  Min. Init. Time / s         8 non-null      float64
#  11  Max. Init. Time / s         8 non-null      float64
# ...

# %%
print("\nSummary statistics of the DataFrame:")
df.describe()
# Out:
# Summary statistics of the DataFrame:
#         id     Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  \
# count  8.0  8.000000    8.000000       8.00000             8.000000    8.0
# mean   5.0  1.750000    3.000000       6.00000           118.463750   10.0
# std    0.0  0.707107    1.069045       2.13809            62.073344    0.0
# min    5.0  1.000000    2.000000       4.00000            37.200000   10.0
# 25%    5.0  1.000000    2.000000       4.00000            79.120000   10.0
# 50%    5.0  2.000000    3.000000       6.00000            93.040000   10.0
# 75%    5.0  2.000000    4.000000       8.00000           173.330000   10.0
# max    5.0  3.000000    4.000000       8.00000           202.150000   10.0
#
#        Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# count                    8.000000                    8.000000
# mean                     0.173750                   29.203750
# std                      0.050973                   13.778026
# ...

# %% [markdown]
# # Task 2:

# %% [markdown]
# • Read Task2 data as a dataframe and call it df
#
# • Get to know it and play a bit with it(describe, show head,show shape...etc)

# %%
import csv
import pandas as pd

# %%
file_path = 'Task2Data.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# 3                        0.20                       40.03
# 4                        0.13                       20.93
#
#    Max. Edge Build Time / s  ...  Max. Init. Time / s  Presim. Time / s  \
# 0                     46.34  ...                 1.01              7.87
# ...

# %%
df.shape
# Out:
# (8, 21)

# %%
data = {
    'Name': ['Sarah', 'Mike', 'Tod', 'David'],
    'height (cm)': [163.50, 171.22, 176.90, 185.63],
    'Age': [44, 32, 35, 40],
    'Position' : ['Manager', 'Fashion designer','Content creator', 'Photographer']
}

# %%
demo_df = pd.DataFrame(data)

# %%
demo_df
# Out:
#     Name  height (cm)  Age          Position
# 0  Sarah       163.50   44           Manager
# 1   Mike       171.22   32  Fashion designer
# 2    Tod       176.90   35   Content creator
# 3  David       185.63   40      Photographer

# %%
demo_df.sort_values("Age")
# Out:
#     Name  height (cm)  Age          Position
# 1   Mike       171.22   32  Fashion designer
# 2    Tod       176.90   35   Content creator
# 3  David       185.63   40      Photographer
# 0  Sarah       163.50   44           Manager

# %%
demo_df.round(2).tail(2)
# Out:
#     Name  height (cm)  Age         Position
# 2    Tod       176.90   35  Content creator
# 3  David       185.63   40     Photographer

# %%
demo_df.sort_values("height (cm)")[1:3]
# Out:
#    Name  height (cm)  Age          Position
# 1  Mike       171.22   32  Fashion designer
# 2   Tod       176.90   35   Content creator

# %%
data = {
    'A': [1.2,1.2,1.2],
    'B': ['2018-02-26', '2018-02-26','2018-02-26'],
    'C': ['This','Column','has'],
    'D' : ['Same','Same',"Same"]
}

# %%
demo2df = pd.DataFrame(data)

# %%
demo2df
# Out:
#      A           B       C     D
# 0  1.2  2018-02-26    This  Same
# 1  1.2  2018-02-26  Column  Same
# 2  1.2  2018-02-26     has  Same

# %% [markdown]
# # Task 3

# %% [markdown]
# Add a column to the Task2 frame form Task 2 called “Program_Runtime*2” which multiplies the Program Runtime by 2

# %%
import pandas as pd

# %%
df['Program_Runtime*2'] = df['Runtime Program / s'] * 2

# %%
df
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
# 6   5      2           4             8                37.20     10     True
# 7   5      3           2             4                96.51     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# ...
